# %%
from math import floor

class field(object):
    def __init__(self, elementary_str, contractions, symbol):
        self.elementary_str = elementary_str #Stores list of N symbols for elementary field factors phi and dphi
        self.elementary = []
        self.contractions = contractions #Stores the indices with respect to which successive elementary factors are linked
                                #e.g., [[0,1],[1,0],[0,1]] for phi^i1 dphi_u1^i1 dphi_u1^i2 phi^i2, [[1,1]] for dphi_u^i dphi_u^i. For N 
                                #elementary fields, N-1 links.
        self.symbol = symbol
        self.generated_terms = []
    def __str__(self):
        return 'elementary_str: ' + str(self.elementary_str) + '\n' \
            + 'contractions: ' + str(self.contractions) + '\n' \
            + 'symbol: ' + str(self.symbol) + '\n' \
            + 'massDim: ' + str(self.massDim()) + '\n' \
            + 'LORrank: ' + str(self.LORrank()) + '\n' \
            + 'ONrank: ' + str(self.ONrank()) 
            
    def __eq__(self, other):
        eq = (self.elementary_str == other.elementary_str) & (self.contractions == other.contractions)
        return eq
    
    #Define get and set functions
    def get_elementary_str(self):
        return self.elementary_str
    def get_elementary(self):
        return self.elementary
    def get_contractions(self):
        return self.contractions
    def get_symbol(self):
        return self.symbol
    
    def set_elementary_str(self, elementary_str):
        self.elementary_str = elementary_str
    def set_elementary(self): #should run this to set list of constituent fields
        for symbol in self.elementary_str:
            if symbol == 'P':
                field1 = field(['P'],[], 'P')
                self.elementary.append(field1)
            elif symbol == 'DP':
                field1_deriv = field(['DP'],[], 'DP')
                self.elementary.append(field1_deriv)
            else:
                print('Error: Symbol must be P or DP.')
    def set_contractions(self, contractions):
        self.contractions = contractions
    def set_symbol(self, symbol):
        self.symbol = symbol
    
    
    
    def massDim(self):
        
        counter = 0
        
        for field in self.get_elementary():
            if field.get_symbol() == 'P':
                counter = counter + 1
            elif field.get_symbol() == 'DP':
                counter = counter + 2
        
        return counter                       

    def LORrank(self):
        '''
        To get LORrank Count number of Lorentz contractions (counter) in contractions. Multiply by 2. Subtract this from 
        the number of Lorentz indices appearing in elementary - namely, the number of 'DP' fields. 
        '''
        counter1 = 0
        for pair in self.get_contractions():
            if pair[0] == 1:
                counter1 = counter1 + 1
            else:
                pass
            
        counter2 = 0
        for field in self.get_elementary():
            if field.get_symbol() == 'DP':
                counter2 = counter2 + 1
            else:
                pass     
        #print("counter1: " + str(counter1))
        #print("counter2: " + str(counter2))
        
        rank = counter2 - 2*counter1
        
        return rank
    
    
    def ONrank(self):
        
        counter1 = 0
        
        #Number of contractions is the number of time a '1' appears in the second index of pairs in contractions
        for pair in self.get_contractions():
            if pair[1] == 1:
                counter1 = counter1 + 1
            else:
                pass
        
        #Number of ON indices is just the number of fields in self.elementary
        counter2 = len(self.get_elementary_str())
            
        rank = counter2 - 2*counter1
        
        return rank
    
    
    def contract(self, other, contraction, symbol_prod):
        '''
        other: elementary field, P or DP
        contraction: pair of integers - [1,0] for contraction in LOR, [0,1] for contraction in ON, [1,1] for both
        symbol_prod: string
        '''
        
        #print("contraction: " + str(contraction))
        
        if contraction == [1,0]:
            contractions_prod = self.get_contractions() + [[1,0]]
        elif contraction == [0,1]:
            contractions_prod = self.get_contractions() + [[0,1]]
        elif contraction == [1,1]:
            contractions_prod = self.get_contractions() + [[1,1]]
        else:
            print("Error: contractions must be [1,0], [0,1], or [1,1]")
            
        
        elementary_str_prod = self.get_elementary_str() + other.get_elementary_str()
        
        prod = field(elementary_str_prod, contractions_prod, symbol_prod)
        
        prod.set_elementary()
        
        return prod
    
    
    def multiply(self, other, symbol_prod=''):
        '''
        Multiplies without contraction
        INPUT:
        self: field object
        other: field object
        symbol_prod: symbol for new field obj output
        
        OUTPUT:
        prod: field object, concatenating self and other, by inserting [0,0] in contractions
        
        '''
        if (not self.get_elementary_str()) or (not other.get_elementary_str()):
            print("one factor is const")
            contractions_prod = self.get_contractions() + other.get_contractions()
        else:
            contractions_prod = self.get_contractions() + [[0,0]] + other.get_contractions()
        
        elementary_str_prod = self.get_elementary_str() + other.get_elementary_str()
        
        prod = field(elementary_str_prod, contractions_prod, symbol_prod)
        
        prod.set_elementary()
        
        return prod
    
    
    
    def generate_connected(self, d):
        '''
        INPUT
        d: non-negative integer, mass dimension up to which to generate field terms
        
        OUTPUT
        terms: list of field terms of mass dimension no larger than d.  
        '''
        
        const = field([],[],'1')
        
        terms = [const]
        
        #print("in generate_connected")
        
        if d >= 2:
            #print("in d>=2")
            field1 = field(['P'],[],'P')
            field2 = field(['P'],[],'P')
            prod = field.contract(field1, field2, [0,1], 'PP')
            terms.append(prod)
        if d >= 4:
            deriv1 = field(['DP'],[],'DP')
            deriv2 = field(['DP'],[],'DP')
            prod = field.contract(deriv1, deriv2, [1,1], 'DPDP')
            terms.append(prod)
        
        field1 = field(['P'],[],'P')
        deriv1 = field(['DP'],[],'DP')
        
        if d < 4:
            return terms
    
        
        root = field.contract(field1, deriv1, [0,1], 'PDP')
        
        while root.massDim() <= d:
            #print("")
            #print("root: ")
            #print(root)
            #print("")
            if root.LORrank() != 0:
                #print("in root.LORrank()!=0")
                deriv1 = field(['DP'],[],'DP')
                root = field.contract(root, deriv1, [1,0], '')
                #print("")
                #print("root: ")
                #print(root)
                #print("")
            
            if root.ONrank() != 0:
                #print("in root.ONrank()!=0")
                field1 = field(['P'],[],'P')
                deriv1 = field(['DP'],[],'DP')
                
                new = field.contract(root, field1, [0,1], '')
                if new.massDim() <= d and new.LORrank() == 0 and new.ONrank() == 0:
                    #print("in new term added")
                    terms.append(new)
                
                root = field.contract(root, deriv1, [0,1], '')
                #print("")
                #print("root: ")
                #print(root)
                #print("")    
        
        return terms
    
    
    '''
    def generate(self, D):
        print("In generate, D = " + str(D))
        if D < 2:
            return [field([], [], '')], [field([], [], '')] 
        if D == 2:
            const = field([], [], '')
            PP = field(['P','P'],[[0,1]],'PP')
            return [const, PP], [const, PP] #return generated terms and cache for higher D's
        else:
            connected_terms_D = field.generate_connected(self, D)
            print("")
            print("Check Connected_terms_D: ")
            for term in connected_terms_D:
                print(term)
                print("")
            
            cache = []
            generated = []
            
            for i in range(len(connected_terms_D)):
                for j in range(len(self.generate(D-1)[1])):
                    prod = field.multiply(connected_terms_D[i], self.generate(D-1)[1][j])
                    cache.append(prod)
            
            for term in cache:
                if term.massDim() <= D:
                    generated.append(term)
               
    '''
    
    def generate(self, D):
        if D < 2:
            print("D should be >= 2.")
            return []
        else:
            d = 2
        
            const = field([], [], '')
            PP = field(['P','P'],[[0,1]],'PP')
            cache = [const, PP]
        
            while(d <= D):
                #print(d)
                connected_terms_d = self.generate_connected(d)
                #print("len(connected_terms_d): " + str(len(connected_terms_d)))
                #print("len(cache): " + str(len(cache)))
                
                cache_len = len(cache)
                
                for i in range(len(connected_terms_d)):
                    for j in range(cache_len):
                        print("i,j:" + str(i) + ", " + str(j))
                        prod = field.multiply(connected_terms_d[i], cache[j])
                        cache.append(prod)
            
                d +=1
            
            generated = []
            
            for term in cache:
                if term.massDim() <= D:
                    generated.append(term)
                
            return generated

# %%
A = field(['P','DP','DP'],[[0,1],[1,0]],'')

# %%
A.generate(6)
# Out:
# 2
# len(connected_terms_d): 2
# len(cache): 2
# i,j:0, 0
# one factor is const
# i,j:0, 1
# one factor is const
# i,j:1, 0
# one factor is const
# i,j:1, 1
# 3
# len(connected_terms_d): 2
# len(cache): 6
# i,j:0, 0
# one factor is const
# i,j:0, 1
# one factor is const
# i,j:0, 2
# one factor is const
# i,j:0, 3
# one factor is const
# i,j:0, 4
# one factor is const
# i,j:0, 5
# one factor is const
# i,j:1, 0
# one factor is const
# i,j:1, 1
# i,j:1, 2
# one factor is const
# i,j:1, 3
# i,j:1, 4
# i,j:1, 5
# 4
# len(connected_terms_d): 3
# len(cache): 18
# i,j:0, 0
# one factor is const
# i,j:0, 1
# one factor is const
# i,j:0, 2
# one factor is const
# i,j:0, 3
# one factor is const
# i,j:0, 4
# one factor is const
# i,j:0, 5
# one factor is const
# i,j:0, 6
# one factor is const
# i,j:0, 7
# one factor is const
# i,j:0, 8
# one factor is const
# i,j:0, 9
# one factor is const
# i,j:0, 10
# one factor is const
# i,j:0, 11
# one factor is const
# i,j:0, 12
# one factor is const
# i,j:0, 13
# one factor is const
# i,j:0, 14
# one factor is const
# i,j:0, 15
# one factor is const
# i,j:0, 16
# one factor is const
# i,j:0, 17
# one factor is const
# i,j:1, 0
# one factor is const
# i,j:1, 1
# i,j:1, 2
# one factor is const
# i,j:1, 3
# i,j:1, 4
# i,j:1, 5
# i,j:1, 6
# one factor is const
# i,j:1, 7
# i,j:1, 8
# one factor is const
# i,j:1, 9
# i,j:1, 10
# i,j:1, 11
# i,j:1, 12
# i,j:1, 13
# i,j:1, 14
# i,j:1, 15
# i,j:1, 16
# i,j:1, 17
# i,j:2, 0
# one factor is const
# i,j:2, 1
# i,j:2, 2
# one factor is const
# i,j:2, 3
# i,j:2, 4
# i,j:2, 5
# i,j:2, 6
# one factor is const
# i,j:2, 7
# i,j:2, 8
# one factor is const
# i,j:2, 9
# i,j:2, 10
# i,j:2, 11
# i,j:2, 12
# i,j:2, 13
# i,j:2, 14
# i,j:2, 15
# i,j:2, 16
# i,j:2, 17
# 5
# len(connected_terms_d): 3
# len(cache): 72
# i,j:0, 0
# one factor is const
# i,j:0, 1
# one factor is const
# i,j:0, 2
# one factor is const
# i,j:0, 3
# one factor is const
# i,j:0, 4
# one factor is const
# i,j:0, 5
# one factor is const
# i,j:0, 6
# one factor is const
# i,j:0, 7
# one factor is const
# i,j:0, 8
# one factor is const
# i,j:0, 9
# one factor is const
# i,j:0, 10
# one factor is const
# i,j:0, 11
# one factor is const
# i,j:0, 12
# one factor is const
# i,j:0, 13
# one factor is const
# i,j:0, 14
# one factor is const
# i,j:0, 15
# one factor is const
# i,j:0, 16
# one factor is const
# i,j:0, 17
# one factor is const
# i,j:0, 18
# one factor is const
# i,j:0, 19
# one factor is const
# i,j:0, 20
# one factor is const
# i,j:0, 21
# one factor is const
# i,j:0, 22
# one factor is const
# i,j:0, 23
# one factor is const
# i,j:0, 24
# one factor is const
# i,j:0, 25
# one factor is const
# i,j:0, 26
# one factor is const
# i,j:0, 27
# one factor is const
# i,j:0, 28
# one factor is const
# i,j:0, 29
# one factor is const
# i,j:0, 30
# one factor is const
# i,j:0, 31
# one factor is const
# i,j:0, 32
# one factor is const
# i,j:0, 33
# one factor is const
# i,j:0, 34
# one factor is const
# i,j:0, 35
# one factor is const
# i,j:0, 36
# one factor is const
# i,j:0, 37
# one factor is const
# i,j:0, 38
# one factor is const
# i,j:0, 39
# one factor is const
# i,j:0, 40
# one factor is const
# i,j:0, 41
# one factor is const
# i,j:0, 42
# one factor is const
# i,j:0, 43
# one factor is const
# i,j:0, 44
# one factor is const
# i,j:0, 45
# one factor is const
# i,j:0, 46
# one factor is const
# i,j:0, 47
# one factor is const
# i,j:0, 48
# one factor is const
# i,j:0, 49
# one factor is const
# i,j:0, 50
# one factor is const
# i,j:0, 51
# one factor is const
# i,j:0, 52
# one factor is const
# i,j:0, 53
# one factor is const
# i,j:0, 54
# one factor is const
# i,j:0, 55
# one factor is const
# i,j:0, 56
# one factor is const
# i,j:0, 57
# one factor is const
# i,j:0, 58
# one factor is const
# i,j:0, 59
# one factor is const
# i,j:0, 60
# one factor is const
# i,j:0, 61
# one factor is const
# i,j:0, 62
# one factor is const
# i,j:0, 63
# one factor is const
# i,j:0, 64
# one factor is const
# i,j:0, 65
# one factor is const
# i,j:0, 66
# one factor is const
# i,j:0, 67
# one factor is const
# i,j:0, 68
# one factor is const
# i,j:0, 69
# one factor is const
# i,j:0, 70
# one factor is const
# i,j:0, 71
# one factor is const
# i,j:1, 0
# one factor is const
# i,j:1, 1
# i,j:1, 2
# one factor is const
# i,j:1, 3
# i,j:1, 4
# i,j:1, 5
# i,j:1, 6
# one factor is const
# i,j:1, 7
# i,j:1, 8
# one factor is const
# i,j:1, 9
# i,j:1, 10
# i,j:1, 11
# i,j:1, 12
# i,j:1, 13
# i,j:1, 14
# i,j:1, 15
# i,j:1, 16
# i,j:1, 17
# i,j:1, 18
# one factor is const
# i,j:1, 19
# i,j:1, 20
# one factor is const
# i,j:1, 21
# i,j:1, 22
# i,j:1, 23
# i,j:1, 24
# one factor is const
# i,j:1, 25
# i,j:1, 26
# one factor is const
# i,j:1, 27
# i,j:1, 28
# i,j:1, 29
# i,j:1, 30
# i,j:1, 31
# i,j:1, 32
# i,j:1, 33
# i,j:1, 34
# i,j:1, 35
# i,j:1, 36
# i,j:1, 37
# i,j:1, 38
# i,j:1, 39
# i,j:1, 40
# i,j:1, 41
# i,j:1, 42
# i,j:1, 43
# i,j:1, 44
# i,j:1, 45
# i,j:1, 46
# i,j:1, 47
# i,j:1, 48
# i,j:1, 49
# i,j:1, 50
# i,j:1, 51
# i,j:1, 52
# i,j:1, 53
# i,j:1, 54
# i,j:1, 55
# i,j:1, 56
# i,j:1, 57
# i,j:1, 58
# i,j:1, 59
# i,j:1, 60
# i,j:1, 61
# i,j:1, 62
# i,j:1, 63
# i,j:1, 64
# i,j:1, 65
# i,j:1, 66
# i,j:1, 67
# i,j:1, 68
# i,j:1, 69
# i,j:1, 70
# i,j:1, 71
# i,j:2, 0
# one factor is const
# i,j:2, 1
# i,j:2, 2
# one factor is const
# i,j:2, 3
# i,j:2, 4
# i,j:2, 5
# i,j:2, 6
# one factor is const
# i,j:2, 7
# i,j:2, 8
# one factor is const
# i,j:2, 9
# i,j:2, 10
# i,j:2, 11
# i,j:2, 12
# i,j:2, 13
# i,j:2, 14
# i,j:2, 15
# i,j:2, 16
# i,j:2, 17
# i,j:2, 18
# one factor is const
# i,j:2, 19
# i,j:2, 20
# one factor is const
# i,j:2, 21
# i,j:2, 22
# i,j:2, 23
# i,j:2, 24
# one factor is const
# i,j:2, 25
# i,j:2, 26
# one factor is const
# i,j:2, 27
# i,j:2, 28
# i,j:2, 29
# i,j:2, 30
# i,j:2, 31
# i,j:2, 32
# i,j:2, 33
# i,j:2, 34
# i,j:2, 35
# i,j:2, 36
# i,j:2, 37
# i,j:2, 38
# i,j:2, 39
# i,j:2, 40
# i,j:2, 41
# i,j:2, 42
# i,j:2, 43
# i,j:2, 44
# i,j:2, 45
# i,j:2, 46
# i,j:2, 47
# i,j:2, 48
# i,j:2, 49
# i,j:2, 50
# i,j:2, 51
# i,j:2, 52
# i,j:2, 53
# i,j:2, 54
# i,j:2, 55
# i,j:2, 56
# i,j:2, 57
# i,j:2, 58
# i,j:2, 59
# i,j:2, 60
# i,j:2, 61
# i,j:2, 62
# i,j:2, 63
# i,j:2, 64
# i,j:2, 65
# i,j:2, 66
# i,j:2, 67
# i,j:2, 68
# i,j:2, 69
# i,j:2, 70
# i,j:2, 71
# 6
# len(connected_terms_d): 4
# len(cache): 288
# i,j:0, 0
# one factor is const
# i,j:0, 1
# one factor is const
# i,j:0, 2
# one factor is const
# i,j:0, 3
# one factor is const
# i,j:0, 4
# one factor is const
# i,j:0, 5
# one factor is const
# i,j:0, 6
# one factor is const
# i,j:0, 7
# one factor is const
# i,j:0, 8
# one factor is const
# i,j:0, 9
# one factor is const
# i,j:0, 10
# one factor is const
# i,j:0, 11
# one factor is const
# i,j:0, 12
# one factor is const
# i,j:0, 13
# one factor is const
# i,j:0, 14
# one factor is const
# i,j:0, 15
# one factor is const
# i,j:0, 16
# one factor is const
# i,j:0, 17
# one factor is const
# i,j:0, 18
# one factor is const
# i,j:0, 19
# one factor is const
# i,j:0, 20
# one factor is const
# i,j:0, 21
# one factor is const
# i,j:0, 22
# one factor is const
# i,j:0, 23
# one factor is const
# i,j:0, 24
# one factor is const
# i,j:0, 25
# one factor is const
# i,j:0, 26
# one factor is const
# i,j:0, 27
# one factor is const
# i,j:0, 28
# one factor is const
# i,j:0, 29
# one factor is const
# i,j:0, 30
# one factor is const
# i,j:0, 31
# one factor is const
# i,j:0, 32
# one factor is const
# i,j:0, 33
# one factor is const
# i,j:0, 34
# one factor is const
# i,j:0, 35
# one factor is const
# i,j:0, 36
# one factor is const
# i,j:0, 37
# one factor is const
# i,j:0, 38
# one factor is const
# i,j:0, 39
# one factor is const
# i,j:0, 40
# one factor is const
# i,j:0, 41
# one factor is const
# i,j:0, 42
# one factor is const
# i,j:0, 43
# one factor is const
# i,j:0, 44
# one factor is const
# i,j:0, 45
# one factor is const
# i,j:0, 46
# one factor is const
# i,j:0, 47
# one factor is const
# i,j:0, 48
# one factor is const
# i,j:0, 49
# one factor is const
# i,j:0, 50
# one factor is const
# i,j:0, 51
# one factor is const
# i,j:0, 52
# one factor is const
# i,j:0, 53
# one factor is const
# i,j:0, 54
# one factor is const
# i,j:0, 55
# one factor is const
# i,j:0, 56
# one factor is const
# i,j:0, 57
# one factor is const
# i,j:0, 58
# one factor is const
# i,j:0, 59
# one factor is const
# i,j:0, 60
# one factor is const
# i,j:0, 61
# one factor is const
# i,j:0, 62
# one factor is const
# i,j:0, 63
# one factor is const
# i,j:0, 64
# one factor is const
# i,j:0, 65
# one factor is const
# i,j:0, 66
# one factor is const
# i,j:0, 67
# one factor is const
# i,j:0, 68
# one factor is const
# i,j:0, 69
# one factor is const
# i,j:0, 70
# one factor is const
# i,j:0, 71
# one factor is const
# i,j:0, 72
# one factor is const
# i,j:0, 73
# one factor is const
# i,j:0, 74
# one factor is const
# i,j:0, 75
# one factor is const
# i,j:0, 76
# one factor is const
# i,j:0, 77
# one factor is const
# i,j:0, 78
# one factor is const
# i,j:0, 79
# one factor is const
# i,j:0, 80
# one factor is const
# i,j:0, 81
# one factor is const
# i,j:0, 82
# one factor is const
# i,j:0, 83
# one factor is const
# i,j:0, 84
# one factor is const
# i,j:0, 85
# one factor is const
# i,j:0, 86
# one factor is const
# i,j:0, 87
# one factor is const
# i,j:0, 88
# one factor is const
# i,j:0, 89
# one factor is const
# i,j:0, 90
# one factor is const
# i,j:0, 91
# one factor is const
# i,j:0, 92
# one factor is const
# i,j:0, 93
# one factor is const
# i,j:0, 94
# one factor is const
# i,j:0, 95
# one factor is const
# i,j:0, 96
# one factor is const
# i,j:0, 97
# one factor is const
# i,j:0, 98
# one factor is const
# i,j:0, 99
# one factor is const
# i,j:0, 100
# one factor is const
# i,j:0, 101
# one factor is const
# i,j:0, 102
# one factor is const
# i,j:0, 103
# one factor is const
# i,j:0, 104
# one factor is const
# i,j:0, 105
# one factor is const
# i,j:0, 106
# one factor is const
# i,j:0, 107
# one factor is const
# i,j:0, 108
# one factor is const
# i,j:0, 109
# one factor is const
# i,j:0, 110
# one factor is const
# i,j:0, 111
# one factor is const
# i,j:0, 112
# one factor is const
# i,j:0, 113
# one factor is const
# i,j:0, 114
# one factor is const
# i,j:0, 115
# one factor is const
# i,j:0, 116
# one factor is const
# i,j:0, 117
# one factor is const
# i,j:0, 118
# one factor is const
# i,j:0, 119
# one factor is const
# i,j:0, 120
# one factor is const
# i,j:0, 121
# one factor is const
# i,j:0, 122
# one factor is const
# i,j:0, 123
# one factor is const
# i,j:0, 124
# one factor is const
# i,j:0, 125
# one factor is const
# i,j:0, 126
# one factor is const
# i,j:0, 127
# one factor is const
# i,j:0, 128
# one factor is const
# i,j:0, 129
# one factor is const
# i,j:0, 130
# one factor is const
# i,j:0, 131
# one factor is const
# i,j:0, 132
# one factor is const
# i,j:0, 133
# one factor is const
# i,j:0, 134
# one factor is const
# i,j:0, 135
# one factor is const
# i,j:0, 136
# one factor is const
# i,j:0, 137
# one factor is const
# i,j:0, 138
# one factor is const
# i,j:0, 139
# one factor is const
# i,j:0, 140
# one factor is const
# i,j:0, 141
# one factor is const
# i,j:0, 142
# one factor is const
# i,j:0, 143
# one factor is const
# i,j:0, 144
# one factor is const
# i,j:0, 145
# one factor is const
# i,j:0, 146
# one factor is const
# i,j:0, 147
# one factor is const
# i,j:0, 148
# one factor is const
# i,j:0, 149
# one factor is const
# i,j:0, 150
# one factor is const
# i,j:0, 151
# one factor is const
# i,j:0, 152
# one factor is const
# i,j:0, 153
# one factor is const
# i,j:0, 154
# one factor is const
# i,j:0, 155
# one factor is const
# i,j:0, 156
# one factor is const
# i,j:0, 157
# one factor is const
# i,j:0, 158
# one factor is const
# i,j:0, 159
# one factor is const
# i,j:0, 160
# one factor is const
# i,j:0, 161
# one factor is const
# i,j:0, 162
# one factor is const
# i,j:0, 163
# one factor is const
# i,j:0, 164
# one factor is const
# i,j:0, 165
# one factor is const
# i,j:0, 166
# one factor is const
# i,j:0, 167
# one factor is const
# i,j:0, 168
# one factor is const
# i,j:0, 169
# one factor is const
# i,j:0, 170
# one factor is const
# i,j:0, 171
# one factor is const
# i,j:0, 172
# one factor is const
# i,j:0, 173
# one factor is const
# i,j:0, 174
# one factor is const
# i,j:0, 175
# one factor is const
# i,j:0, 176
# one factor is const
# i,j:0, 177
# one factor is const
# i,j:0, 178
# one factor is const
# i,j:0, 179
# one factor is const
# i,j:0, 180
# one factor is const
# i,j:0, 181
# one factor is const
# i,j:0, 182
# one factor is const
# i,j:0, 183
# one factor is const
# i,j:0, 184
# one factor is const
# i,j:0, 185
# one factor is const
# i,j:0, 186
# one factor is const
# i,j:0, 187
# one factor is const
# i,j:0, 188
# one factor is const
# i,j:0, 189
# one factor is const
# i,j:0, 190
# one factor is const
# i,j:0, 191
# one factor is const
# i,j:0, 192
# one factor is const
# i,j:0, 193
# one factor is const
# i,j:0, 194
# one factor is const
# i,j:0, 195
# one factor is const
# i,j:0, 196
# one factor is const
# i,j:0, 197
# one factor is const
# i,j:0, 198
# one factor is const
# i,j:0, 199
# one factor is const
# i,j:0, 200
# one factor is const
# i,j:0, 201
# one factor is const
# i,j:0, 202
# one factor is const
# i,j:0, 203
# one factor is const
# i,j:0, 204
# one factor is const
# i,j:0, 205
# one factor is const
# i,j:0, 206
# one factor is const
# i,j:0, 207
# one factor is const
# i,j:0, 208
# one factor is const
# i,j:0, 209
# one factor is const
# i,j:0, 210
# one factor is const
# i,j:0, 211
# one factor is const
# i,j:0, 212
# one factor is const
# i,j:0, 213
# one factor is const
# i,j:0, 214
# one factor is const
# i,j:0, 215
# one factor is const
# i,j:0, 216
# one factor is const
# i,j:0, 217
# one factor is const
# i,j:0, 218
# one factor is const
# i,j:0, 219
# one factor is const
# i,j:0, 220
# one factor is const
# i,j:0, 221
# one factor is const
# i,j:0, 222
# one factor is const
# i,j:0, 223
# one factor is const
# i,j:0, 224
# one factor is const
# i,j:0, 225
# one factor is const
# i,j:0, 226
# one factor is const
# i,j:0, 227
# one factor is const
# i,j:0, 228
# one factor is const
# i,j:0, 229
# one factor is const
# i,j:0, 230
# one factor is const
# i,j:0, 231
# one factor is const
# i,j:0, 232
# one factor is const
# i,j:0, 233
# one factor is const
# i,j:0, 234
# one factor is const
# i,j:0, 235
# one factor is const
# i,j:0, 236
# one factor is const
# i,j:0, 237
# one factor is const
# i,j:0, 238
# one factor is const
# i,j:0, 239
# one factor is const
# i,j:0, 240
# one factor is const
# i,j:0, 241
# one factor is const
# i,j:0, 242
# one factor is const
# i,j:0, 243
# one factor is const
# i,j:0, 244
# one factor is const
# i,j:0, 245
# one factor is const
# i,j:0, 246
# one factor is const
# i,j:0, 247
# one factor is const
# i,j:0, 248
# one factor is const
# i,j:0, 249
# one factor is const
# i,j:0, 250
# one factor is const
# i,j:0, 251
# one factor is const
# i,j:0, 252
# one factor is const
# i,j:0, 253
# one factor is const
# i,j:0, 254
# one factor is const
# i,j:0, 255
# one factor is const
# i,j:0, 256
# one factor is const
# i,j:0, 257
# one factor is const
# i,j:0, 258
# one factor is const
# i,j:0, 259
# one factor is const
# i,j:0, 260
# one factor is const
# i,j:0, 261
# one factor is const
# i,j:0, 262
# one factor is const
# i,j:0, 263
# one factor is const
# i,j:0, 264
# one factor is const
# i,j:0, 265
# one factor is const
# i,j:0, 266
# one factor is const
# i,j:0, 267
# one factor is const
# i,j:0, 268
# one factor is const
# i,j:0, 269
# one factor is const
# i,j:0, 270
# one factor is const
# i,j:0, 271
# one factor is const
# i,j:0, 272
# one factor is const
# i,j:0, 273
# one factor is const
# i,j:0, 274
# one factor is const
# i,j:0, 275
# one factor is const
# i,j:0, 276
# one factor is const
# i,j:0, 277
# one factor is const
# i,j:0, 278
# one factor is const
# i,j:0, 279
# one factor is const
# i,j:0, 280
# one factor is const
# i,j:0, 281
# one factor is const
# i,j:0, 282
# one factor is const
# i,j:0, 283
# one factor is const
# i,j:0, 284
# one factor is const
# i,j:0, 285
# one factor is const
# i,j:0, 286
# one factor is const
# i,j:0, 287
# one factor is const
# i,j:1, 0
# one factor is const
# i,j:1, 1
# i,j:1, 2
# one factor is const
# i,j:1, 3
# i,j:1, 4
# i,j:1, 5
# i,j:1, 6
# one factor is const
# i,j:1, 7
# i,j:1, 8
# one factor is const
# i,j:1, 9
# i,j:1, 10
# i,j:1, 11
# i,j:1, 12
# i,j:1, 13
# i,j:1, 14
# i,j:1, 15
# i,j:1, 16
# i,j:1, 17
# i,j:1, 18
# one factor is const
# i,j:1, 19
# i,j:1, 20
# one factor is const
# i,j:1, 21
# i,j:1, 22
# i,j:1, 23
# i,j:1, 24
# one factor is const
# i,j:1, 25
# i,j:1, 26
# one factor is const
# i,j:1, 27
# i,j:1, 28
# i,j:1, 29
# i,j:1, 30
# i,j:1, 31
# i,j:1, 32
# i,j:1, 33
# i,j:1, 34
# i,j:1, 35
# i,j:1, 36
# i,j:1, 37
# i,j:1, 38
# i,j:1, 39
# i,j:1, 40
# i,j:1, 41
# i,j:1, 42
# i,j:1, 43
# i,j:1, 44
# i,j:1, 45
# i,j:1, 46
# i,j:1, 47
# i,j:1, 48
# i,j:1, 49
# i,j:1, 50
# i,j:1, 51
# i,j:1, 52
# i,j:1, 53
# i,j:1, 54
# i,j:1, 55
# i,j:1, 56
# i,j:1, 57
# i,j:1, 58
# i,j:1, 59
# i,j:1, 60
# i,j:1, 61
# i,j:1, 62
# i,j:1, 63
# i,j:1, 64
# i,j:1, 65
# i,j:1, 66
# i,j:1, 67
# i,j:1, 68
# i,j:1, 69
# i,j:1, 70
# i,j:1, 71
# i,j:1, 72
# one factor is const
# i,j:1, 73
# i,j:1, 74
# one factor is const
# i,j:1, 75
# i,j:1, 76
# i,j:1, 77
# i,j:1, 78
# one factor is const
# i,j:1, 79
# i,j:1, 80
# one factor is const
# i,j:1, 81
# i,j:1, 82
# i,j:1, 83
# i,j:1, 84
# i,j:1, 85
# i,j:1, 86
# i,j:1, 87
# i,j:1, 88
# i,j:1, 89
# i,j:1, 90
# one factor is const
# i,j:1, 91
# i,j:1, 92
# one factor is const
# i,j:1, 93
# i,j:1, 94
# i,j:1, 95
# i,j:1, 96
# one factor is const
# i,j:1, 97
# i,j:1, 98
# one factor is const
# i,j:1, 99
# i,j:1, 100
# i,j:1, 101
# i,j:1, 102
# i,j:1, 103
# i,j:1, 104
# i,j:1, 105
# i,j:1, 106
# i,j:1, 107
# i,j:1, 108
# i,j:1, 109
# i,j:1, 110
# i,j:1, 111
# i,j:1, 112
# i,j:1, 113
# i,j:1, 114
# i,j:1, 115
# i,j:1, 116
# i,j:1, 117
# i,j:1, 118
# i,j:1, 119
# i,j:1, 120
# i,j:1, 121
# i,j:1, 122
# i,j:1, 123
# i,j:1, 124
# i,j:1, 125
# i,j:1, 126
# i,j:1, 127
# i,j:1, 128
# i,j:1, 129
# i,j:1, 130
# i,j:1, 131
# i,j:1, 132
# i,j:1, 133
# i,j:1, 134
# i,j:1, 135
# i,j:1, 136
# i,j:1, 137
# i,j:1, 138
# i,j:1, 139
# i,j:1, 140
# i,j:1, 141
# i,j:1, 142
# i,j:1, 143
# i,j:1, 144
# i,j:1, 145
# i,j:1, 146
# i,j:1, 147
# i,j:1, 148
# i,j:1, 149
# i,j:1, 150
# i,j:1, 151
# i,j:1, 152
# i,j:1, 153
# i,j:1, 154
# i,j:1, 155
# i,j:1, 156
# i,j:1, 157
# i,j:1, 158
# i,j:1, 159
# i,j:1, 160
# i,j:1, 161
# i,j:1, 162
# i,j:1, 163
# i,j:1, 164
# i,j:1, 165
# i,j:1, 166
# i,j:1, 167
# i,j:1, 168
# i,j:1, 169
# i,j:1, 170
# i,j:1, 171
# i,j:1, 172
# i,j:1, 173
# i,j:1, 174
# i,j:1, 175
# i,j:1, 176
# i,j:1, 177
# i,j:1, 178
# i,j:1, 179
# i,j:1, 180
# i,j:1, 181
# i,j:1, 182
# i,j:1, 183
# i,j:1, 184
# i,j:1, 185
# i,j:1, 186
# i,j:1, 187
# i,j:1, 188
# i,j:1, 189
# i,j:1, 190
# i,j:1, 191
# i,j:1, 192
# i,j:1, 193
# i,j:1, 194
# i,j:1, 195
# i,j:1, 196
# i,j:1, 197
# i,j:1, 198
# i,j:1, 199
# i,j:1, 200
# i,j:1, 201
# i,j:1, 202
# i,j:1, 203
# i,j:1, 204
# i,j:1, 205
# i,j:1, 206
# i,j:1, 207
# i,j:1, 208
# i,j:1, 209
# i,j:1, 210
# i,j:1, 211
# i,j:1, 212
# i,j:1, 213
# i,j:1, 214
# i,j:1, 215
# i,j:1, 216
# i,j:1, 217
# i,j:1, 218
# i,j:1, 219
# i,j:1, 220
# i,j:1, 221
# i,j:1, 222
# i,j:1, 223
# i,j:1, 224
# i,j:1, 225
# i,j:1, 226
# i,j:1, 227
# i,j:1, 228
# i,j:1, 229
# i,j:1, 230
# i,j:1, 231
# i,j:1, 232
# i,j:1, 233
# i,j:1, 234
# i,j:1, 235
# i,j:1, 236
# i,j:1, 237
# i,j:1, 238
# i,j:1, 239
# i,j:1, 240
# i,j:1, 241
# i,j:1, 242
# i,j:1, 243
# i,j:1, 244
# i,j:1, 245
# i,j:1, 246
# i,j:1, 247
# i,j:1, 248
# i,j:1, 249
# i,j:1, 250
# i,j:1, 251
# i,j:1, 252
# i,j:1, 253
# i,j:1, 254
# i,j:1, 255
# i,j:1, 256
# i,j:1, 257
# i,j:1, 258
# i,j:1, 259
# i,j:1, 260
# i,j:1, 261
# i,j:1, 262
# i,j:1, 263
# i,j:1, 264
# i,j:1, 265
# i,j:1, 266
# i,j:1, 267
# i,j:1, 268
# i,j:1, 269
# i,j:1, 270
# i,j:1, 271
# i,j:1, 272
# i,j:1, 273
# i,j:1, 274
# i,j:1, 275
# i,j:1, 276
# i,j:1, 277
# i,j:1, 278
# i,j:1, 279
# i,j:1, 280
# i,j:1, 281
# i,j:1, 282
# i,j:1, 283
# i,j:1, 284
# i,j:1, 285
# i,j:1, 286
# i,j:1, 287
# i,j:2, 0
# one factor is const
# i,j:2, 1
# i,j:2, 2
# one factor is const
# i,j:2, 3
# i,j:2, 4
# i,j:2, 5
# i,j:2, 6
# one factor is const
# i,j:2, 7
# i,j:2, 8
# one factor is const
# i,j:2, 9
# i,j:2, 10
# i,j:2, 11
# i,j:2, 12
# i,j:2, 13
# i,j:2, 14
# i,j:2, 15
# i,j:2, 16
# i,j:2, 17
# i,j:2, 18
# one factor is const
# i,j:2, 19
# i,j:2, 20
# one factor is const
# i,j:2, 21
# i,j:2, 22
# i,j:2, 23
# i,j:2, 24
# one factor is const
# i,j:2, 25
# i,j:2, 26
# one factor is const
# i,j:2, 27
# i,j:2, 28
# i,j:2, 29
# i,j:2, 30
# i,j:2, 31
# i,j:2, 32
# i,j:2, 33
# i,j:2, 34
# i,j:2, 35
# i,j:2, 36
# i,j:2, 37
# i,j:2, 38
# i,j:2, 39
# i,j:2, 40
# i,j:2, 41
# i,j:2, 42
# i,j:2, 43
# i,j:2, 44
# i,j:2, 45
# i,j:2, 46
# i,j:2, 47
# i,j:2, 48
# i,j:2, 49
# i,j:2, 50
# i,j:2, 51
# i,j:2, 52
# i,j:2, 53
# i,j:2, 54
# i,j:2, 55
# i,j:2, 56
# i,j:2, 57
# i,j:2, 58
# i,j:2, 59
# i,j:2, 60
# i,j:2, 61
# i,j:2, 62
# i,j:2, 63
# i,j:2, 64
# i,j:2, 65
# i,j:2, 66
# i,j:2, 67
# i,j:2, 68
# i,j:2, 69
# i,j:2, 70
# i,j:2, 71
# i,j:2, 72
# one factor is const
# i,j:2, 73
# i,j:2, 74
# one factor is const
# i,j:2, 75
# i,j:2, 76
# i,j:2, 77
# i,j:2, 78
# one factor is const
# i,j:2, 79
# i,j:2, 80
# one factor is const
# i,j:2, 81
# i,j:2, 82
# i,j:2, 83
# i,j:2, 84
# i,j:2, 85
# i,j:2, 86
# i,j:2, 87
# i,j:2, 88
# i,j:2, 89
# i,j:2, 90
# one factor is const
# i,j:2, 91
# i,j:2, 92
# one factor is const
# i,j:2, 93
# i,j:2, 94
# i,j:2, 95
# i,j:2, 96
# one factor is const
# i,j:2, 97
# i,j:2, 98
# one factor is const
# i,j:2, 99
# i,j:2, 100
# i,j:2, 101
# i,j:2, 102
# i,j:2, 103
# i,j:2, 104
# i,j:2, 105
# i,j:2, 106
# i,j:2, 107
# i,j:2, 108
# i,j:2, 109
# i,j:2, 110
# i,j:2, 111
# i,j:2, 112
# i,j:2, 113
# i,j:2, 114
# i,j:2, 115
# i,j:2, 116
# i,j:2, 117
# i,j:2, 118
# i,j:2, 119
# i,j:2, 120
# i,j:2, 121
# i,j:2, 122
# i,j:2, 123
# i,j:2, 124
# i,j:2, 125
# i,j:2, 126
# i,j:2, 127
# i,j:2, 128
# i,j:2, 129
# i,j:2, 130
# i,j:2, 131
# i,j:2, 132
# i,j:2, 133
# i,j:2, 134
# i,j:2, 135
# i,j:2, 136
# i,j:2, 137
# i,j:2, 138
# i,j:2, 139
# i,j:2, 140
# i,j:2, 141
# i,j:2, 142
# i,j:2, 143
# i,j:2, 144
# i,j:2, 145
# i,j:2, 146
# i,j:2, 147
# i,j:2, 148
# i,j:2, 149
# i,j:2, 150
# i,j:2, 151
# i,j:2, 152
# i,j:2, 153
# i,j:2, 154
# i,j:2, 155
# i,j:2, 156
# i,j:2, 157
# i,j:2, 158
# i,j:2, 159
# i,j:2, 160
# i,j:2, 161
# i,j:2, 162
# i,j:2, 163
# i,j:2, 164
# i,j:2, 165
# i,j:2, 166
# i,j:2, 167
# i,j:2, 168
# i,j:2, 169
# i,j:2, 170
# i,j:2, 171
# i,j:2, 172
# i,j:2, 173
# i,j:2, 174
# i,j:2, 175
# i,j:2, 176
# i,j:2, 177
# i,j:2, 178
# i,j:2, 179
# i,j:2, 180
# i,j:2, 181
# i,j:2, 182
# i,j:2, 183
# i,j:2, 184
# i,j:2, 185
# i,j:2, 186
# i,j:2, 187
# i,j:2, 188
# i,j:2, 189
# i,j:2, 190
# i,j:2, 191
# i,j:2, 192
# i,j:2, 193
# i,j:2, 194
# i,j:2, 195
# i,j:2, 196
# i,j:2, 197
# i,j:2, 198
# i,j:2, 199
# i,j:2, 200
# i,j:2, 201
# i,j:2, 202
# i,j:2, 203
# i,j:2, 204
# i,j:2, 205
# i,j:2, 206
# i,j:2, 207
# i,j:2, 208
# i,j:2, 209
# i,j:2, 210
# i,j:2, 211
# i,j:2, 212
# i,j:2, 213
# i,j:2, 214
# i,j:2, 215
# i,j:2, 216
# i,j:2, 217
# i,j:2, 218
# i,j:2, 219
# i,j:2, 220
# i,j:2, 221
# i,j:2, 222
# i,j:2, 223
# i,j:2, 224
# i,j:2, 225
# i,j:2, 226
# i,j:2, 227
# i,j:2, 228
# i,j:2, 229
# i,j:2, 230
# i,j:2, 231
# i,j:2, 232
# i,j:2, 233
# i,j:2, 234
# i,j:2, 235
# i,j:2, 236
# i,j:2, 237
# i,j:2, 238
# i,j:2, 239
# i,j:2, 240
# i,j:2, 241
# i,j:2, 242
# i,j:2, 243
# i,j:2, 244
# i,j:2, 245
# i,j:2, 246
# i,j:2, 247
# i,j:2, 248
# i,j:2, 249
# i,j:2, 250
# i,j:2, 251
# i,j:2, 252
# i,j:2, 253
# i,j:2, 254
# i,j:2, 255
# i,j:2, 256
# i,j:2, 257
# i,j:2, 258
# i,j:2, 259
# i,j:2, 260
# i,j:2, 261
# i,j:2, 262
# i,j:2, 263
# i,j:2, 264
# i,j:2, 265
# i,j:2, 266
# i,j:2, 267
# i,j:2, 268
# i,j:2, 269
# i,j:2, 270
# i,j:2, 271
# i,j:2, 272
# i,j:2, 273
# i,j:2, 274
# i,j:2, 275
# i,j:2, 276
# i,j:2, 277
# i,j:2, 278
# i,j:2, 279
# i,j:2, 280
# i,j:2, 281
# i,j:2, 282
# i,j:2, 283
# i,j:2, 284
# i,j:2, 285
# i,j:2, 286
# i,j:2, 287
# i,j:3, 0
# one factor is const
# i,j:3, 1
# i,j:3, 2
# one factor is const
# i,j:3, 3
# i,j:3, 4
# i,j:3, 5
# i,j:3, 6
# one factor is const
# i,j:3, 7
# i,j:3, 8
# one factor is const
# i,j:3, 9
# i,j:3, 10
# i,j:3, 11
# i,j:3, 12
# i,j:3, 13
# i,j:3, 14
# i,j:3, 15
# i,j:3, 16
# i,j:3, 17
# i,j:3, 18
# one factor is const
# i,j:3, 19
# i,j:3, 20
# one factor is const
# i,j:3, 21
# i,j:3, 22
# i,j:3, 23
# i,j:3, 24
# one factor is const
# i,j:3, 25
# i,j:3, 26
# one factor is const
# i,j:3, 27
# i,j:3, 28
# i,j:3, 29
# i,j:3, 30
# i,j:3, 31
# i,j:3, 32
# i,j:3, 33
# i,j:3, 34
# i,j:3, 35
# i,j:3, 36
# i,j:3, 37
# i,j:3, 38
# i,j:3, 39
# i,j:3, 40
# i,j:3, 41
# i,j:3, 42
# i,j:3, 43
# i,j:3, 44
# i,j:3, 45
# i,j:3, 46
# i,j:3, 47
# i,j:3, 48
# i,j:3, 49
# i,j:3, 50
# i,j:3, 51
# i,j:3, 52
# i,j:3, 53
# i,j:3, 54
# i,j:3, 55
# i,j:3, 56
# i,j:3, 57
# i,j:3, 58
# i,j:3, 59
# i,j:3, 60
# i,j:3, 61
# i,j:3, 62
# i,j:3, 63
# i,j:3, 64
# i,j:3, 65
# i,j:3, 66
# i,j:3, 67
# i,j:3, 68
# i,j:3, 69
# i,j:3, 70
# i,j:3, 71
# i,j:3, 72
# one factor is const
# i,j:3, 73
# i,j:3, 74
# one factor is const
# i,j:3, 75
# i,j:3, 76
# i,j:3, 77
# i,j:3, 78
# one factor is const
# i,j:3, 79
# i,j:3, 80
# one factor is const
# i,j:3, 81
# i,j:3, 82
# i,j:3, 83
# i,j:3, 84
# i,j:3, 85
# i,j:3, 86
# i,j:3, 87
# i,j:3, 88
# i,j:3, 89
# i,j:3, 90
# one factor is const
# i,j:3, 91
# i,j:3, 92
# one factor is const
# i,j:3, 93
# i,j:3, 94
# i,j:3, 95
# i,j:3, 96
# one factor is const
# i,j:3, 97
# i,j:3, 98
# one factor is const
# i,j:3, 99
# i,j:3, 100
# i,j:3, 101
# i,j:3, 102
# i,j:3, 103
# i,j:3, 104
# i,j:3, 105
# i,j:3, 106
# i,j:3, 107
# i,j:3, 108
# i,j:3, 109
# i,j:3, 110
# i,j:3, 111
# i,j:3, 112
# i,j:3, 113
# i,j:3, 114
# i,j:3, 115
# i,j:3, 116
# i,j:3, 117
# i,j:3, 118
# i,j:3, 119
# i,j:3, 120
# i,j:3, 121
# i,j:3, 122
# i,j:3, 123
# i,j:3, 124
# i,j:3, 125
# i,j:3, 126
# i,j:3, 127
# i,j:3, 128
# i,j:3, 129
# i,j:3, 130
# i,j:3, 131
# i,j:3, 132
# i,j:3, 133
# i,j:3, 134
# i,j:3, 135
# i,j:3, 136
# i,j:3, 137
# i,j:3, 138
# i,j:3, 139
# i,j:3, 140
# i,j:3, 141
# i,j:3, 142
# i,j:3, 143
# i,j:3, 144
# i,j:3, 145
# i,j:3, 146
# i,j:3, 147
# i,j:3, 148
# i,j:3, 149
# i,j:3, 150
# i,j:3, 151
# i,j:3, 152
# i,j:3, 153
# i,j:3, 154
# i,j:3, 155
# i,j:3, 156
# i,j:3, 157
# i,j:3, 158
# i,j:3, 159
# i,j:3, 160
# i,j:3, 161
# i,j:3, 162
# i,j:3, 163
# i,j:3, 164
# i,j:3, 165
# i,j:3, 166
# i,j:3, 167
# i,j:3, 168
# i,j:3, 169
# i,j:3, 170
# i,j:3, 171
# i,j:3, 172
# i,j:3, 173
# i,j:3, 174
# i,j:3, 175
# i,j:3, 176
# i,j:3, 177
# i,j:3, 178
# i,j:3, 179
# i,j:3, 180
# i,j:3, 181
# i,j:3, 182
# i,j:3, 183
# i,j:3, 184
# i,j:3, 185
# i,j:3, 186
# i,j:3, 187
# i,j:3, 188
# i,j:3, 189
# i,j:3, 190
# i,j:3, 191
# i,j:3, 192
# i,j:3, 193
# i,j:3, 194
# i,j:3, 195
# i,j:3, 196
# i,j:3, 197
# i,j:3, 198
# i,j:3, 199
# i,j:3, 200
# i,j:3, 201
# i,j:3, 202
# i,j:3, 203
# i,j:3, 204
# i,j:3, 205
# i,j:3, 206
# i,j:3, 207
# i,j:3, 208
# i,j:3, 209
# i,j:3, 210
# i,j:3, 211
# i,j:3, 212
# i,j:3, 213
# i,j:3, 214
# i,j:3, 215
# i,j:3, 216
# i,j:3, 217
# i,j:3, 218
# i,j:3, 219
# i,j:3, 220
# i,j:3, 221
# i,j:3, 222
# i,j:3, 223
# i,j:3, 224
# i,j:3, 225
# i,j:3, 226
# i,j:3, 227
# i,j:3, 228
# i,j:3, 229
# i,j:3, 230
# i,j:3, 231
# i,j:3, 232
# i,j:3, 233
# i,j:3, 234
# i,j:3, 235
# i,j:3, 236
# i,j:3, 237
# i,j:3, 238
# i,j:3, 239
# i,j:3, 240
# i,j:3, 241
# i,j:3, 242
# i,j:3, 243
# i,j:3, 244
# i,j:3, 245
# i,j:3, 246
# i,j:3, 247
# i,j:3, 248
# i,j:3, 249
# i,j:3, 250
# i,j:3, 251
# i,j:3, 252
# i,j:3, 253
# i,j:3, 254
# i,j:3, 255
# i,j:3, 256
# i,j:3, 257
# i,j:3, 258
# i,j:3, 259
# i,j:3, 260
# i,j:3, 261
# i,j:3, 262
# i,j:3, 263
# i,j:3, 264
# i,j:3, 265
# i,j:3, 266
# i,j:3, 267
# i,j:3, 268
# i,j:3, 269
# i,j:3, 270
# i,j:3, 271
# i,j:3, 272
# i,j:3, 273
# i,j:3, 274
# i,j:3, 275
# i,j:3, 276
# i,j:3, 277
# i,j:3, 278
# i,j:3, 279
# i,j:3, 280
# i,j:3, 281
# i,j:3, 282
# i,j:3, 283
# i,j:3, 284
# i,j:3, 285
# i,j:3, 286
# i,j:3, 287
# [<__main__.field at 0x119760d68>,
#  <__main__.field at 0x1198b07b8>,
#  <__main__.field at 0x11970c898>,
#  <__main__.field at 0x1197c79e8>,
#  <__main__.field at 0x119d41978>,
#  <__main__.field at 0x119d41b70>,
#  <__main__.field at 0x119b46828>,
#  <__main__.field at 0x119b465c0>,
#  <__main__.field at 0x119b469b0>,
#  <__main__.field at 0x119b46c88>,
#  <__main__.field at 0x119b46eb8>,
#  <__main__.field at 0x119b464e0>,
#  <__main__.field at 0x1199a4780>,
#  <__main__.field at 0x1199a41d0>,
#  <__main__.field at 0x1199a4860>,
#  <__main__.field at 0x1199a4ba8>,
#  <__main__.field at 0x1199a4da0>,
#  <__main__.field at 0x1199a4fd0>,
#  <__main__.field at 0x11989bac8>,
#  <__main__.field at 0x1197b4f98>,
#  <__main__.field at 0x11970c748>,
#  <__main__.field at 0x119a820b8>,
#  <__main__.field at 0x119a82a20>,
#  <__main__.field at 0x119309ef0>,
#  <__main__.field at 0x11998f5f8>,
#  <__main__.field at 0x1196dda20>,
#  <__main__.field at 0x119a91828>,
#  <__main__.field at 0x119a91f98>,
#  <__main__.field at 0x119a910f0>,
#  <__main__.field at 0x1199619b0>,
#  <__main__.field at 0x119aad6a0>,
#  <__main__.field at 0x1197c77f0>,
#  <__main__.field at 0x119aad4e0>,
#  <__main__.field at 0x119aad710>,
#  <__main__.field at 0x119aad9b0>,
#  <__main__.field at 0x119aaddd8>,
#  <__main__.field at 0x119aad588>,
#  <__main__.field at 0x119aad908>,
#  <__main__.field at 0x1195f3e80>,
#  <__main__.field at 0x119d41d30>,
#  <__main__.field at 0x119ab4080>,
#  <__main__.field at 0x119ab42e8>,
#  <__main__.field at 0x119ab4588>,
#  <__main__.field at 0x119ab4780>,
#  <__main__.field at 0x119ab49e8>,
#  <__main__.field at 0x119ab4cf8>,
#  <__main__.field at 0x119ab4be0>,
#  <__main__.field at 0x119d41b38>,
#  <__main__.field at 0x119ab40b8>,
#  <__main__.field at 0x1198a9668>,
#  <__main__.field at 0x1198a9f98>,
#  <__main__.field at 0x117d5d518>,
#  <__main__.field at 0x1198a9400>,
#  <__main__.field at 0x11970c240>,
#  <__main__.field at 0x119b55518>,
#  <__main__.field at 0x119b557f0>,
#  <__main__.field at 0x119b55ac8>,
#  <__main__.field at 0x1197c7a90>,
#  <__main__.field at 0x119b5c518>,
#  <__main__.field at 0x119b5ca20>,
#  <__main__.field at 0x119b5c160>,
#  <__main__.field at 0x119d328d0>,
#  <__main__.field at 0x119d324e0>,
#  <__main__.field at 0x119d32908>,
#  <__main__.field at 0x119d32e80>,
#  <__main__.field at 0x11970c518>,
#  <__main__.field at 0x119c63f60>,
#  <__main__.field at 0x119c63438>,
#  <__main__.field at 0x119c63c18>,
#  <__main__.field at 0x119c630b8>,
#  <__main__.field at 0x119c63400>,
#  <__main__.field at 0x119c6ac50>,
#  <__main__.field at 0x119c6af98>,
#  <__main__.field at 0x119a01ac8>,
#  <__main__.field at 0x119a01780>,
#  <__main__.field at 0x119a01048>,
#  <__main__.field at 0x119a01240>,
#  <__main__.field at 0x119b469e8>,
#  <__main__.field at 0x119a01e80>,
#  <__main__.field at 0x1199d4898>,
#  <__main__.field at 0x1199d4160>,
#  <__main__.field at 0x1199d49e8>,
#  <__main__.field at 0x1199d4e10>,
#  <__main__.field at 0x1199ff908>,
#  <__main__.field at 0x1199ff128>,
#  <__main__.field at 0x1199ff2b0>,
#  <__main__.field at 0x1199ff390>,
#  <__main__.field at 0x1199ff588>,
#  <__main__.field at 0x1199ff748>,
#  <__main__.field at 0x1199879b0>,
#  <__main__.field at 0x1199878d0>,
#  <__main__.field at 0x119b46cc0>,
#  <__main__.field at 0x119987438>,
#  <__main__.field at 0x119987eb8>,
#  <__main__.field at 0x119e4da90>,
#  <__main__.field at 0x119e4d198>,
#  <__main__.field at 0x119b46da0>,
#  <__main__.field at 0x119e4ddd8>,
#  <__main__.field at 0x119e64ef0>,
#  <__main__.field at 0x119e64198>,
#  <__main__.field at 0x119e642e8>,
#  <__main__.field at 0x119e64748>,
#  <__main__.field at 0x119e64908>,
#  <__main__.field at 0x119e64b38>,
#  <__main__.field at 0x119e64c88>,
#  <__main__.field at 0x119e6fd30>,
#  <__main__.field at 0x119e6f390>,
#  <__main__.field at 0x119e6f470>,
#  <__main__.field at 0x119e6f5f8>,
#  <__main__.field at 0x119e6f860>,
#  <__main__.field at 0x119e6fa58>,
#  <__main__.field at 0x119e6fe80>,
#  <__main__.field at 0x119a4df98>,
#  <__main__.field at 0x119e7ca20>,
#  <__main__.field at 0x119e7c240>,
#  <__main__.field at 0x119e7c518>,
#  <__main__.field at 0x119e7c710>,
#  <__main__.field at 0x119e7c9e8>,
#  <__main__.field at 0x119e09e80>,
#  <__main__.field at 0x119e097f0>,
#  <__main__.field at 0x119e090f0>,
#  <__main__.field at 0x1199a4898>,
#  <__main__.field at 0x119e094a8>,
#  <__main__.field at 0x119e09a90>,
#  <__main__.field at 0x119e09da0>,
#  <__main__.field at 0x119e09fd0>,
#  <__main__.field at 0x119e157f0>,
#  <__main__.field at 0x119e15048>,
#  <__main__.field at 0x119e15828>,
#  <__main__.field at 0x119e15d30>,
#  <__main__.field at 0x119e1e198>,
#  <__main__.field at 0x119e1e2b0>,
#  <__main__.field at 0x119e1e518>,
#  <__main__.field at 0x119e1e5f8>,
#  <__main__.field at 0x119e1e7f0>,
#  <__main__.field at 0x119e1e9e8>,
#  <__main__.field at 0x119e1ee10>,
#  <__main__.field at 0x119e1ef28>,
#  <__main__.field at 0x119e2a7b8>,
#  <__main__.field at 0x119e2a2e8>,
#  <__main__.field at 0x119e2a278>,
#  <__main__.field at 0x11970c0b8>,
#  <__main__.field at 0x119e2a6a0>,
#  <__main__.field at 0x119e2aa20>,
#  <__main__.field at 0x119e2ada0>,
#  <__main__.field at 0x119e2af98>,
#  <__main__.field at 0x119c13f98>,
#  <__main__.field at 0x119a40438>,
#  <__main__.field at 0x11989b9e8>,
#  <__main__.field at 0x119aeee10>,
#  <__main__.field at 0x119aeec50>,
#  <__main__.field at 0x119aee518>,
#  <__main__.field at 0x11989bcc0>,
#  <__main__.field at 0x119aee320>,
#  <__main__.field at 0x119aee438>,
#  <__main__.field at 0x119843710>,
#  <__main__.field at 0x119aee780>,
#  <__main__.field at 0x119843978>,
#  <__main__.field at 0x119afce80>,
#  <__main__.field at 0x119afc710>,
#  <__main__.field at 0x119afc3c8>,
#  <__main__.field at 0x119afc2e8>,
#  <__main__.field at 0x119afcbe0>,
#  <__main__.field at 0x119afcf98>,
#  <__main__.field at 0x119ade9e8>,
#  <__main__.field at 0x119ade390>,
#  <__main__.field at 0x119ade668>,
#  <__main__.field at 0x119ade860>,
#  <__main__.field at 0x1197a65f8>,
#  <__main__.field at 0x119ac9438>,
#  <__main__.field at 0x119ac9048>,
#  <__main__.field at 0x119ac9978>,
#  <__main__.field at 0x119ac9cf8>,
#  <__main__.field at 0x119a82e10>,
#  <__main__.field at 0x119af0358>,
#  <__main__.field at 0x119af0b38>,
#  <__main__.field at 0x119b32630>,
#  <__main__.field at 0x119a829e8>,
#  <__main__.field at 0x11997eeb8>,
#  <__main__.field at 0x119b246d8>,
#  <__main__.field at 0x1198937f0>,
#  <__main__.field at 0x119893828>,
#  <__main__.field at 0x119767c50>,
#  <__main__.field at 0x119b19908>,
#  <__main__.field at 0x119b19208>,
#  <__main__.field at 0x119b196d8>,
#  <__main__.field at 0x119b19860>,
#  <__main__.field at 0x119b19ac8>,
#  <__main__.field at 0x119793860>,
#  <__main__.field at 0x119a91208>,
#  <__main__.field at 0x119b064a8>,
#  <__main__.field at 0x119b06d30>,
#  <__main__.field at 0x119b1a6a0>,
#  <__main__.field at 0x119b1a828>,
#  <__main__.field at 0x119b1abe0>,
#  <__main__.field at 0x119b1aeb8>,
#  <__main__.field at 0x119f66f28>,
#  <__main__.field at 0x119f66160>,
#  <__main__.field at 0x119a91940>,
#  <__main__.field at 0x119f66668>,
#  <__main__.field at 0x119f66908>,
#  <__main__.field at 0x119f66b00>,
#  <__main__.field at 0x119f66ef0>,
#  <__main__.field at 0x119970d30>,
#  <__main__.field at 0x119f567f0>,
#  <__main__.field at 0x119f56c18>,
#  <__main__.field at 0x119f6c4e0>,
#  <__main__.field at 0x119f6c940>,
#  <__main__.field at 0x119c55208>,
#  <__main__.field at 0x119c552e8>,
#  <__main__.field at 0x119c7f400>,
#  <__main__.field at 0x119c7fef0>,
#  <__main__.field at 0x119c7f6d8>,
#  <__main__.field at 0x119c7f278>,
#  <__main__.field at 0x119c73630>,
#  <__main__.field at 0x119961940>,
#  <__main__.field at 0x119c732b0>,
#  <__main__.field at 0x119c73470>,
#  <__main__.field at 0x119c73668>,
#  <__main__.field at 0x119c737f0>,
#  <__main__.field at 0x119c73c18>,
#  <__main__.field at 0x119aad0b8>,
#  <__main__.field at 0x119b79940>,
#  <__main__.field at 0x119b794e0>,
#  <__main__.field at 0x119b796a0>,
#  <__main__.field at 0x119aad1d0>,
#  <__main__.field at 0x119b79d30>,
#  <__main__.field at 0x119b79f28>,
#  <__main__.field at 0x119b79860>,
#  <__main__.field at 0x119b79e10>,
#  <__main__.field at 0x119b797f0>,
#  <__main__.field at 0x1198b7898>,
#  <__main__.field at 0x1198b7eb8>,
#  <__main__.field at 0x119aad518>,
#  <__main__.field at 0x1198b72b0>,
#  <__main__.field at 0x1198b7048>,
#  <__main__.field at 0x1198be5f8>,
#  <__main__.field at 0x1198beb38>,
#  <__main__.field at 0x1198bef98>,
#  <__main__.field at 0x1198bea90>,
#  <__main__.field at 0x1198be128>,
#  <__main__.field at 0x1198be828>,
#  <__main__.field at 0x119aad940>,
#  <__main__.field at 0x119c462b0>,
#  <__main__.field at 0x1198675f8>,
#  <__main__.field at 0x119867128>,
#  <__main__.field at 0x119aadcf8>,
#  <__main__.field at 0x119867048>,
#  <__main__.field at 0x1198675c0>,
#  <__main__.field at 0x1198c48d0>,
#  <__main__.field at 0x119aade10>,
#  <__main__.field at 0x1198c44a8>,
#  <__main__.field at 0x1198c46a0>,
#  <__main__.field at 0x1198c4ac8>,
#  <__main__.field at 0x1198ccb38>,
#  <__main__.field at 0x1198ccd30>,
#  <__main__.field at 0x1198cc630>,
#  <__main__.field at 0x1198cce48>,
#  <__main__.field at 0x119a67438>,
#  <__main__.field at 0x11986e748>,
#  <__main__.field at 0x11986ea90>,
#  <__main__.field at 0x1198d4550>,
#  <__main__.field at 0x119d411d0>,
#  <__main__.field at 0x1198d4dd8>,
#  <__main__.field at 0x119a6e780>,
#  <__main__.field at 0x119a6e550>,
#  <__main__.field at 0x119ab4128>,
#  <__main__.field at 0x1198dc9e8>,
#  <__main__.field at 0x1198dceb8>,
#  <__main__.field at 0x1198dcac8>,
#  <__main__.field at 0x1198dc1d0>,
#  <__main__.field at 0x1198e25f8>,
#  <__main__.field at 0x1198e2ac8>,
#  <__main__.field at 0x119e582b0>,
#  <__main__.field at 0x119e583c8>,
#  <__main__.field at 0x119e58e10>,
#  <__main__.field at 0x119e58c18>,
#  <__main__.field at 0x119e58358>,
#  <__main__.field at 0x119e58978>,
#  <__main__.field at 0x119ab4320>,
#  <__main__.field at 0x119c4d518>,
#  <__main__.field at 0x119c4de10>,
#  <__main__.field at 0x119c4d860>,
#  <__main__.field at 0x119c4d240>,
#  <__main__.field at 0x1198a9908>,
#  <__main__.field at 0x119ab4400>,
#  <__main__.field at 0x119ab49b0>,
#  <__main__.field at 0x119e52fd0>,
#  <__main__.field at 0x119e524a8>,
#  <__main__.field at 0x119e52198>,
#  <__main__.field at 0x119e52630>,
#  <__main__.field at 0x119e52be0>,
#  <__main__.field at 0x119e52e48>,
#  <__main__.field at 0x119b552b0>,
#  <__main__.field at 0x119e52240>,
#  <__main__.field at 0x1198f7550>,
#  <__main__.field at 0x1198f75c0>,
#  <__main__.field at 0x1198f7cc0>,
#  <__main__.field at 0x1198f7e48>,
#  <__main__.field at 0x119b554e0>,
#  <__main__.field at 0x1198f79b0>,
#  <__main__.field at 0x1198f7470>,
#  <__main__.field at 0x1198f78d0>,
#  <__main__.field at 0x1198f7978>,
#  <__main__.field at 0x117d70f28>,
#  <__main__.field at 0x119878518>,
#  <__main__.field at 0x11970c7f0>,
#  <__main__.field at 0x119e3db38>,
#  <__main__.field at 0x119e3d438>,
#  <__main__.field at 0x119b558d0>,
#  <__main__.field at 0x119e3dda0>,
#  <__main__.field at 0x119e3dd30>,
#  <__main__.field at 0x119b55320>,
#  <__main__.field at 0x119e3d048>,
#  <__main__.field at 0x1198fd080>,
#  <__main__.field at 0x1198fdd30>,
#  <__main__.field at 0x1198fdf98>,
#  <__main__.field at 0x1198fd7b8>,
#  <__main__.field at 0x1198fde48>,
#  <__main__.field at 0x1198fd9b0>,
#  <__main__.field at 0x119b55390>,
#  <__main__.field at 0x119e36358>,
#  <__main__.field at 0x119e36a58>,
#  <__main__.field at 0x119e36630>,
#  <__main__.field at 0x119e36518>,
#  <__main__.field at 0x11972c4e0>,
#  <__main__.field at 0x119907630>,
#  <__main__.field at 0x119b5cf28>,
#  <__main__.field at 0x119e2f5f8>,
#  <__main__.field at 0x119e2fac8>,
#  <__main__.field at 0x119e2fc88>,
#  <__main__.field at 0x119e2fa90>,
#  <__main__.field at 0x119758f28>,
#  <__main__.field at 0x11990e358>,
#  <__main__.field at 0x11990ea90>,
#  <__main__.field at 0x119b5c470>,
#  <__main__.field at 0x119913b00>,
#  <__main__.field at 0x119913780>,
#  <__main__.field at 0x119a9e5c0>,
#  <__main__.field at 0x119a9ea58>,
#  <__main__.field at 0x119a9ecc0>,
#  <__main__.field at 0x119a9ec88>,
#  <__main__.field at 0x119d32f60>,
#  <__main__.field at 0x1197a05f8>,
#  <__main__.field at 0x119929a90>,
#  <__main__.field at 0x119d32518>,
#  <__main__.field at 0x119929278>,
#  <__main__.field at 0x119c372e8>,
#  <__main__.field at 0x11992f780>,
#  <__main__.field at 0x11992ff98>,
#  <__main__.field at 0x11992fda0>,
#  <__main__.field at 0x119936d68>,
#  <__main__.field at 0x119936eb8>,
#  <__main__.field at 0x119936a90>,
#  <__main__.field at 0x1199363c8>,
#  <__main__.field at 0x119a8a780>,
#  <__main__.field at 0x119a8a080>,
#  <__main__.field at 0x11987f048>,
#  <__main__.field at 0x119943dd8>,
#  <__main__.field at 0x1199434a8>,
#  <__main__.field at 0x119d32240>,
#  <__main__.field at 0x119943e80>,
#  <__main__.field at 0x119943320>,
#  <__main__.field at 0x11994cbe0>,
#  <__main__.field at 0x11994cd68>,
#  <__main__.field at 0x11994c7b8>,
#  <__main__.field at 0x119859860>,
#  <__main__.field at 0x1198596a0>,
#  <__main__.field at 0x119a61be0>,
#  <__main__.field at 0x119d74898>,
#  <__main__.field at 0x119d743c8>,
#  <__main__.field at 0x119d74240>,
#  <__main__.field at 0x119d74c50>,
#  <__main__.field at 0x119d74e80>,
#  <__main__.field at 0x119d7a9b0>,
#  <__main__.field at 0x119d7a128>,
#  <__main__.field at 0x119d7a630>,
#  <__main__.field at 0x119d7ac50>,
#  <__main__.field at 0x119d7aef0>,
#  <__main__.field at 0x1199959e8>,
#  <__main__.field at 0x119995f28>,
#  <__main__.field at 0x1198a1898>,
#  <__main__.field at 0x119a97eb8>,
#  <__main__.field at 0x119aa6668>,
#  <__main__.field at 0x119ba9588>,
#  <__main__.field at 0x119ba93c8>,
#  <__main__.field at 0x119bb0e80>,
#  <__main__.field at 0x119bb02e8>,
#  <__main__.field at 0x119bc1160>,
#  <__main__.field at 0x119bc1390>,
#  <__main__.field at 0x119bc1550>,
#  <__main__.field at 0x119b46908>,
#  <__main__.field at 0x119bc1940>,
#  <__main__.field at 0x117d38cf8>,
#  <__main__.field at 0x119b8e6d8>,
#  <__main__.field at 0x119b8e208>,
#  <__main__.field at 0x119b8e3c8>,
#  <__main__.field at 0x119b8e5c0>,
#  <__main__.field at 0x119b8ee80>,
#  <__main__.field at 0x119acf940>,
#  <__main__.field at 0x1196b7080>,
#  <__main__.field at 0x1199ad208>,
#  <__main__.field at 0x119b3e898>,
#  <__main__.field at 0x119a01908>,
#  <__main__.field at 0x119b3eda0>,
#  <__main__.field at 0x119b4d400>,
#  <__main__.field at 0x119a017f0>,
#  <__main__.field at 0x119b4d860>,
#  <__main__.field at 0x119b4df60>,
#  <__main__.field at 0x119b634a8>,
#  <__main__.field at 0x119a011d0>,
#  <__main__.field at 0x119a01160>,
#  <__main__.field at 0x119d1a0f0>,
#  <__main__.field at 0x119a01128>,
#  <__main__.field at 0x119b21080>,
#  <__main__.field at 0x119b214e0>,
#  <__main__.field at 0x119ae5908>,
#  <__main__.field at 0x119ae5a20>,
#  <__main__.field at 0x119ae5c88>,
#  <__main__.field at 0x119ae5dd8>,
#  <__main__.field at 0x119ae5f60>,
#  <__main__.field at 0x1199d4d68>,
#  <__main__.field at 0x119ae13c8>,
#  <__main__.field at 0x119ae14e0>,
#  <__main__.field at 0x1199d4da0>,
#  <__main__.field at 0x119ae17b8>,
#  <__main__.field at 0x119ae1940>,
#  <__main__.field at 0x119ae1ac8>,
#  <__main__.field at 0x119ae1cc0>,
#  <__main__.field at 0x119ae1e48>,
#  <__main__.field at 0x119e81080>,
#  <__main__.field at 0x119e81208>,
#  <__main__.field at 0x119e813c8>,
#  <__main__.field at 0x119e818d0>,
#  <__main__.field at 0x119e819b0>,
#  <__main__.field at 0x119e81ba8>,
#  <__main__.field at 0x119e81cc0>,
#  <__main__.field at 0x1199ffc18>,
#  <__main__.field at 0x119e81f98>,
#  <__main__.field at 0x119e70208>,
#  <__main__.field at 0x119e70320>,
#  <__main__.field at 0x119e704e0>,
#  <__main__.field at 0x119e705f8>,
#  <__main__.field at 0x119e70780>,
#  <__main__.field at 0x1199ff668>,
#  <__main__.field at 0x119e70ac8>,
#  <__main__.field at 0x119e70c50>,
#  <__main__.field at 0x119e70e48>,
#  <__main__.field at 0x119e70fd0>,
#  <__main__.field at 0x119e7a1d0>,
#  <__main__.field at 0x119e7a630>,
#  <__main__.field at 0x119e7a7b8>,
#  <__main__.field at 0x119e7a9b0>,
#  <__main__.field at 0x119e7ab00>,
#  <__main__.field at 0x119e7acf8>,
#  <__main__.field at 0x119e1c198>,
#  <__main__.field at 0x119e1c320>,
#  <__main__.field at 0x119e1c4e0>,
#  <__main__.field at 0x119e1c668>,
#  <__main__.field at 0x119e1c860>,
#  <__main__.field at 0x119e1ccc0>,
#  <__main__.field at 0x119e19160>,
#  <__main__.field at 0x119e19b00>,
#  <__main__.field at 0x119e19e80>,
#  <__main__.field at 0x119e266d8>,
#  <__main__.field at 0x119e26a58>,
#  <__main__.field at 0x119f4d208>,
#  <__main__.field at 0x119f4d320>,
#  <__main__.field at 0x119f4d518>,
#  <__main__.field at 0x119f4d630>,
#  <__main__.field at 0x119f4d7b8>,
#  <__main__.field at 0x119f4d940>,
#  <__main__.field at 0x119f4dba8>,
#  <__main__.field at 0x11965d048>,
#  <__main__.field at 0x119c4d4e0>,
#  <__main__.field at 0x119c4dc88>,
#  <__main__.field at 0x119c4d780>,
#  <__main__.field at 0x119662518>,
#  <__main__.field at 0x119e58e80>,
#  <__main__.field at 0x119e58a90>,
#  <__main__.field at 0x1198e9c18>,
#  <__main__.field at 0x1198e29e8>,
#  <__main__.field at 0x1198e25c0>,
#  <__main__.field at 0x1198a9978>,
#  <__main__.field at 0x1198dc160>,
#  <__main__.field at 0x119a6e208>,
#  <__main__.field at 0x1198d4080>,
#  <__main__.field at 0x1198d4128>,
#  <__main__.field at 0x1198d4e10>,
#  <__main__.field at 0x119a67cc0>,
#  <__main__.field at 0x1198cc2e8>,
#  <__main__.field at 0x1198cc0f0>,
#  <__main__.field at 0x1198c4f98>,
#  <__main__.field at 0x1198c4710>,
#  <__main__.field at 0x119867400>,
#  <__main__.field at 0x1198677f0>,
#  <__main__.field at 0x117dcd860>,
#  <__main__.field at 0x119ab4048>,
#  <__main__.field at 0x119ab4ac8>,
#  <__main__.field at 0x1198beb00>,
#  <__main__.field at 0x1198b7f28>,
#  <__main__.field at 0x119ab4cc0>,
#  <__main__.field at 0x119b79f60>,
#  <__main__.field at 0x119b799b0>,
#  <__main__.field at 0x119b79b70>,
#  <__main__.field at 0x119aad160>,
#  <__main__.field at 0x119c73940>,
#  <__main__.field at 0x119c735c0>,
#  <__main__.field at 0x119c73278>,
#  <__main__.field at 0x119c73080>,
#  <__main__.field at 0x1198599b0>,
#  <__main__.field at 0x119ab4a20>,
#  <__main__.field at 0x119f6c908>,
#  <__main__.field at 0x119f567b8>,
#  <__main__.field at 0x119b1aba8>,
#  <__main__.field at 0x119a91630>,
#  <__main__.field at 0x119a82860>,
#  <__main__.field at 0x119ade898>,
#  <__main__.field at 0x119afcfd0>,
#  <__main__.field at 0x119afc6d8>,
#  <__main__.field at 0x119aee908>,
#  <__main__.field at 0x119a402e8>,
#  <__main__.field at 0x119c13a58>,
#  <__main__.field at 0x119e52128>,
#  <__main__.field at 0x119e2a160>,
#  <__main__.field at 0x119e1eef0>,
#  <__main__.field at 0x119e1ec88>,
#  <__main__.field at 0x119e521d0>,
#  <__main__.field at 0x119e7cba8>,
#  <__main__.field at 0x119e52438>,
#  <__main__.field at 0x119e7c748>,
#  <__main__.field at 0x1199a42e8>,
#  <__main__.field at 0x1199a4208>,
#  <__main__.field at 0x119e526a0>,
#  <__main__.field at 0x119e6fba8>,
#  <__main__.field at 0x119e64b70>,
#  <__main__.field at 0x119e64780>,
#  <__main__.field at 0x119e64550>,
#  <__main__.field at 0x119b46710>,
#  <__main__.field at 0x119987b38>,
#  <__main__.field at 0x119b900f0>,
#  <__main__.field at 0x119b90668>,
#  <__main__.field at 0x119ba01d0>,
#  <__main__.field at 0x119ba0630>,
#  <__main__.field at 0x119d66e48>,
#  <__main__.field at 0x119d6c5f8>,
#  <__main__.field at 0x1198f7588>,
#  <__main__.field at 0x119d6cc50>,
#  <__main__.field at 0x119ec8358>,
#  <__main__.field at 0x119ec86a0>,
#  <__main__.field at 0x1198f7d30>,
#  <__main__.field at 0x119b55438>,
#  <__main__.field at 0x119a26320>,
#  <__main__.field at 0x119b55710>,
#  <__main__.field at 0x119a265f8>,
#  <__main__.field at 0x1198f7668>,
#  <__main__.field at 0x119a26860>,
#  <__main__.field at 0x119a26c18>,
#  <__main__.field at 0x119a26d30>,
#  <__main__.field at 0x119a26ef0>,
#  <__main__.field at 0x119a10048>,
#  <__main__.field at 0x119a101d0>,
#  <__main__.field at 0x119a10518>,
#  <__main__.field at 0x119a10860>,
#  <__main__.field at 0x119a220f0>,
#  <__main__.field at 0x119a22208>,
#  <__main__.field at 0x119a223c8>,
#  <__main__.field at 0x119a224e0>,
#  <__main__.field at 0x119a22630>,
#  <__main__.field at 0x119a229e8>,
#  <__main__.field at 0x119a22b00>,
#  <__main__.field at 0x119878470>,
#  <__main__.field at 0x119a22dd8>,
#  <__main__.field at 0x119a22f60>,
#  <__main__.field at 0x119a362e8>,
#  <__main__.field at 0x119a36630>,
#  <__main__.field at 0x119a36e10>,
#  <__main__.field at 0x119a2a198>,
#  <__main__.field at 0x119a2a940>,
#  <__main__.field at 0x119a2acc0>,
#  <__main__.field at 0x117ceb1d0>,
#  <__main__.field at 0x119a287f0>,
#  <__main__.field at 0x119a28ac8>,
#  <__main__.field at 0x119e3ddd8>,
#  <__main__.field at 0x119a28cf8>,
#  <__main__.field at 0x119a350f0>,
#  <__main__.field at 0x119a35208>,
#  <__main__.field at 0x119a35400>,
#  <__main__.field at 0x119a35518>,
#  <__main__.field at 0x119a356a0>,
#  <__main__.field at 0x119a35a20>,
#  <__main__.field at 0x119a35da0>,
#  <__main__.field at 0x119a315c0>,
#  <__main__.field at 0x119a316d8>,
#  <__main__.field at 0x119e3dcf8>,
#  <__main__.field at 0x119a319b0>,
#  <__main__.field at 0x119a31b38>,
#  <__main__.field at 0x119a31f28>,
#  <__main__.field at 0x119e3da58>,
#  <__main__.field at 0x119bd5240>,
#  <__main__.field at 0x119bd5358>,
#  <__main__.field at 0x119e3da20>,
#  <__main__.field at 0x119bd5828>,
#  <__main__.field at 0x119bd5b70>,
#  <__main__.field at 0x119bf13c8>,
#  <__main__.field at 0x119bf1748>,
#  <__main__.field at 0x119bf1f60>,
#  <__main__.field at 0x119bf62e8>,
#  <__main__.field at 0x119bead30>,
#  <__main__.field at 0x119bd9128>,
#  <__main__.field at 0x119bd98d0>,
#  <__main__.field at 0x119bd9c18>,
#  <__main__.field at 0x119dc3240>,
#  <__main__.field at 0x119dc3588>,
#  <__main__.field at 0x119dc3d30>,
#  <__main__.field at 0x119dcd0b8>,
#  <__main__.field at 0x119ae2240>,
#  <__main__.field at 0x119ac7cc0>,
#  <__main__.field at 0x119b18fd0>,
#  <__main__.field at 0x119b214a8>,
#  <__main__.field at 0x119ad6b00>,
#  <__main__.field at 0x119c4dd68>,
#  <__main__.field at 0x119b8eb38>,
#  <__main__.field at 0x119e586a0>,
#  <__main__.field at 0x119f2ba90>,
#  <__main__.field at 0x119f2be48>,
#  <__main__.field at 0x119f316a0>,
#  <__main__.field at 0x119f31a58>,
#  <__main__.field at 0x119f400f0>,
#  <__main__.field at 0x119f404a8>,
#  <__main__.field at 0x119f40cf8>,
#  <__main__.field at 0x119cc70f0>]

# %%
B = field(['P','DP','DP'],[[0,1],[1,0]],'PDPDP')

# %%
A == B
# Out:
# True

# %%
mylist = [A,B]

# %%
len(mylist)
# Out:
# 2

# %%
set(mylist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-b352bcae5975> in <module>()
# ----> 1 set(mylist)
#
# TypeError: unhashable type: 'field'
